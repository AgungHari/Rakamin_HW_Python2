# %%
order = 10
visit  = 8
if visit >=10:
    syarat1 = True
    if order >= 10:
        syarat2 = True
        result = 'lolos'
    else:
        syarat2 = False
        result = 'tidak lolos'
else:
    syarat1 = False
    if order>= 10:
        syarat2 = True
        result = 'tidak lolos'
    else:
        syarat2 = False
        result = 'tidak lolos'
print('Syarat 1:', syarat1)
print('Syarat 2:', syarat2)
print('Hasil:', result)
# Out:
# Syarat 1: False
# Syarat 2: True
# Hasil: tidak lolos

# %%
usia = 5

if usia < 6:
    kelompok = 'agung'
if usia <=12 :
    kelompok = 'wahu'

print(kelompok)
# Out:
# wahu

# %%
a = 0
b = 2
c= 2
while a < 9:
    b= b*c+2
    a= a + 2
print(b, a)
# Out:
# 126 10

# %%
a = 10
def pangkat(a,n):
    pangkat = a **n
    a=+10
    return pangkat

# %%
pangkat(2, 3)
print(a)
# Out:
# 10

# %%
def perkalian(a,b):
    perkalian = a * b
    return perkalian
print(perkalian(5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       2     perkalian = a * b
#       3     return perkalian
# ----> 4 print(perkalian(5))
#
# TypeError: perkalian() missing 1 required positional argument: 'b'

# %%
def kalkulator(a,b):
    penjumlahan = a + b
    pengurangan = a - b
    perkalian = a * b
    return penjumlahan, pengurangan, perkalian

agung = kalkulator(5, 6)
print('hasilnya',agung[1],agung)
# Out:
# (11, -1, 30)

# %%
def formulasi1(x):
    hasil = (x + 10)
    return hasil

def formulasi2(x):
    hasil = formulasi1(x) *2
    return hasil

formulasi2(10)
# Out:
# 40

# %%
courier = ['JNE', 'JNT' ,'TIKI','SICEPAT', 'POS']
n_pasang = 0 
for i in courier:
    for j in courier:
        if i != j:
            n_pasang += 1

print(n_pasang)
# Out:
# 20
